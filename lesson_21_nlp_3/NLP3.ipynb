# %% [markdown]
# Задание 1: Реализовать Bag of words & tfidf на jokes.csv (в архиве)

# %%
# !pip install --upgrade nltk gensim bokeh umap-learn

import itertools
import string

import numpy as np
import umap
from nltk.tokenize import WordPunctTokenizer

from matplotlib import pyplot as plt

from IPython.display import clear_output

import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Готовые модели

# %%
import gensim.downloader as api
model = api.load('glove-twitter-25')
model.most_similar(positive=["coder", "money"], negative=["brain"])
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded
# [('realtor', 0.8265186548233032),
#  ('gfx', 0.8249695897102356),
#  ('caterers', 0.798202395439148),
#  ('beatmaker', 0.7936854362487793),
#  ('recruiter', 0.7892400622367859),
#  ('sfi', 0.784467339515686),
#  ('sosh', 0.7840631604194641),
#  ('promoter', 0.7838252186775208),
#  ('smallbusiness', 0.7786215543746948),
#  ('promoters', 0.7764680981636047)]

# %%
import bs4 as bs
import urllib.request
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')

scrapped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Artificial_intelligence')
article = scrapped_data.read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:
    article_text += p.text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Cleaing the text
processed_article = article_text.lower()
processed_article = re.sub('[^a-zA-Z]', ' ', processed_article )
processed_article = re.sub(r'\s+', ' ', processed_article)

# Preparing the dataset
all_sentences = nltk.sent_tokenize(processed_article)

all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# Removing Stop Words
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if w not in stopwords.words('english')]

# %%
from gensim.models import Word2Vec
word2vec = Word2Vec(all_words, min_count=2)

# %%
vocabulary = word2vec.wv.vocab
print(vocabulary)
# Out:
# {'artificial': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57710>, 'intelligence': <gensim.models.keyedvectors.Vocab object at 0x7f6142b577d0>, 'ai': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57950>, 'demonstrated': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57c50>, 'machines': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57ad0>, 'natural': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57ed0>, 'displayed': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57cd0>, 'including': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57dd0>, 'humans': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57c90>, 'research': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57d10>, 'defined': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57b50>, 'field': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57f90>, 'study': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57b90>, 'intelligent': <gensim.models.keyedvectors.Vocab object at 0x7f6142b574d0>, 'agents': <gensim.models.keyedvectors.Vocab object at 0x7f6142b57250>, 'system': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c2d0>, 'perceives': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c6d0>, 'environment': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c490>, 'takes': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c510>, 'actions': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c190>, 'maximize': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c050>, 'achieving': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c850>, 'goals': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c8d0>, 'term': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c810>, 'previously': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c990>, 'used': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ca50>, 'describe': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5cdd0>, 'display': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5cd90>, 'human': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c0d0>, 'cognitive': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ce50>, 'skills': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c610>, 'mind': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ced0>, 'learning': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5c110>, 'problem': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4b610>, 'solving': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4bcd0>, 'definition': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4b950>, 'since': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4bf10>, 'rejected': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4bbd0>, 'researchers': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4bd10>, 'terms': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4b510>, 'acting': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4b650>, 'limit': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4bf50>, 'applications': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4be90>, 'include': <gensim.models.keyedvectors.Vocab object at 0x7f6142b4b6d0>, 'advanced': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5a310>, 'web': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5abd0>, 'search': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5acd0>, 'engines': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ab10>, 'e': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5af50>, 'g': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ae50>, 'google': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ac50>, 'recommendation': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5ad50>, 'systems': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5aa50>, 'youtube': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5aa90>, 'amazon': <gensim.models.keyedvectors.Vocab object at 0x7f6142b5a990>, 'netflix': <gensim.models.keyedve ...

# %%
v1 = word2vec.wv['artificial']

# %%
sim_words = word2vec.wv.most_similar('intelligence')
sim_words
# Out:
# [('human', 0.40131208300590515),
#  ('problems', 0.3698444366455078),
#  ('regression', 0.35327690839767456),
#  ('needed', 0.3361377716064453),
#  ('techniques', 0.33528855443000793),
#  ('learning', 0.3300536274909973),
#  ('system', 0.3230702877044678),
#  ('many', 0.32068172097206116),
#  ('beings', 0.32066810131073),
#  ('became', 0.3198379874229431)]

# %% [markdown]
# Задание 2: на базе датасета обучить модель
#
# # выгружаем датасет:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt -nc
